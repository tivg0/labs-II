# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import RealData, Model, ODR
import sys
sys.path.append("../../..")
from baseLabs import *

# %%
f, Vin, uVin, Vout, uVout, G, uG = getData("ninv11.txt")
plot(f,G,np.zeros(len(f)),uG,"G(f) - Não Inversor, G=11","f (Hz)","G","Pontos experimentais",hlines=[10,5])
f = np.delete(f,[0,10,11])
G = np.delete(G,[0,10,11])
uG = np.delete(uG,[0,10,11])

# %%
f, Vin, uVin, Vout, uVout, G, uG = getData("ninv101.txt")
print(np.sort(f))
plot(f,G,np.zeros(len(f)),uG,"G(f) - Não Inversor, G=101","f (Hz)","G","Pontos experimentais",hlines=[100,50])
# Out:
# [   100.   1000.   5000.   7000.  10000.  13000.  15000.  20000.  25000.
#   30000.  40000.  50000.  60000.  75000.  90000. 100000.]

# %%
f, Vin, uVin, Vout, uVout, G, uG = getData("dif.txt")
plot(f,G,np.zeros(len(f)),uG,"G(f) - Diferenciador","f (Hz)","G","Pontos experimentais")
