# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.odr import RealData, Model, ODR
import sys
sys.path.append("../../..")
from baseLabs import *

# %%
f, Vin, uVin, Vout, uVout, G, uG = getData("ninv11.txt")
plot(f,G,np.zeros(len(f)),uG,"G(f) - Não Inversor, G=11","f (Hz)","G","Pontos experimentais")

# %%
f, Vin, uVin, Vout, uVout, G, uG, phi = getData("inv.txt")
plot(f,G,np.zeros(len(f)),uG,"G(f) - Inversor, G=10","f (Hz)","G","Pontos experimentais")

# %%
f, Vin, uVin, Vout, uVout, G, uG = getData("ninv101.txt")
plot(f,G,np.zeros(len(f)),uG,"G(f) - Não Inversor, G=101","f (Hz)","G","Pontos experimentais")

# %%
f, Vin, uVin, Vout, uVout, G, uG = getData("dif.txt")
plot(f,G,np.zeros(len(f)),uG,"G(f) - Diferenciador","f (Hz)","G","Pontos experimentais")
